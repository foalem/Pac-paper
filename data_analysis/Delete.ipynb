# %%
import os
import pandas as pd
import shutil
import stat

# %%
def handle_remove_readonly(func, path, _):
    """Clear read-only flag and retry deletion."""
    os.chmod(path, stat.S_IWRITE)
    func(path)

def clean_clone_directory(dataframe, clone_path):
    # Normalize full_name column to match folder names (replace `/` with `_`)
    valid_folders = set(dataframe['full_name'].str.replace('/', '_', regex=False))

    # List all folders in the clone directory
    all_folders = [f for f in os.listdir(clone_path) if os.path.isdir(os.path.join(clone_path, f))]

    # Identify and remove folders not in the valid set
    folders_to_delete = [f for f in all_folders if f not in valid_folders]

    for folder in folders_to_delete:
        folder_path = os.path.join(clone_path, folder)
        try:
            shutil.rmtree(folder_path, onerror=handle_remove_readonly)
            print(f"Deleted: {folder_path}")
        except Exception as e:
            print(f"Error deleting {folder_path}: {e}")

# %%
# Example usage
# Load your actual dataframe from file
df = pd.read_csv("pac_usage_summary_updated.csv")
clean_clone_directory(df, "C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone")
# Out:
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\094459__cedar-flask-demo
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\1Strategy__cloud-custodian-demo
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\1upD__propper-2013
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\3scale-labs__kiper
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\404954-TomasRivetta__Api-Cine
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\4linux__541: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\4linux__541\\provision\\ansible\\files\\data\\docker\\registry\\v2\\repositories\\4linux-app\\_layers\\sha256\\484e9c88ed5711f99424794dcba0746f7532f8c8d2e129d84daa5af229f41551'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\4linux__543
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\5t33__tf-cloud-workspaces-demo
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\a2-4am__4cade
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\a2d24__python-opa-wasm
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aavarghese__opa-schema-examples
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ACED-IDP__data_model
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\acryldata__datahub-cloudformation
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\adamjimenez__shiftedit
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\adhar-io__adhar
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\AdminTurnedDevOps__kubernetes-examples: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\AdminTurnedDevOps__kubernetes-examples\\codify-k8s-manifest\\cdk8s\\nginxdeployment\\imports\\k8s\\k8s_KubePriorityLevelConfigurationListV1Beta1__no_runtime_type_checking.go'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\AdminTurnedDevOps__kubernetes-real-world-course
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\AfricanAgroAid__AARR-Backend
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ai-solution-eng__frameworks
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aileron-gateway__aileron-gateway
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ajcwebdev__a-first-look
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\akbarali2019__C-with-.NET-Framework: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\akbarali2019__C-with-.NET-Framework\\EventHandlingTimerExample\\EventHandlingTimerExample\\obj\\Debug\\netcoreapp3.1\\EventHandlingTimerExample.csproj.AssemblyReference.cache'
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\akudrati__Azure-Policy: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\akudrati__Azure-Policy\\samples\\GuestConfiguration\\package-samples\\configurations\\InstalledApplicationForLinux\\installed_application_linux_inspec_controls\\controls\\linux.rb'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\akunull__piloslib
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\alcideio__rbac-tool
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\alephdata__offshoreleaks
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Alex-Infnet__asp_net_infnet: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\Alex-Infnet__asp_net_infnet\\AspNetDate\\obj\\.store\\dotnet-aspnet-codegenerator\\7.0.0\\dotnet-aspnet-codegenerator\\7.0.0\\tools\\net7.0\\any\\build\\microsoft.visualstudio.web.codegeneration.tools.targets'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\AlexRogalskiy__android-patterns
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\AlexRogalskiy__kotlin-patterns
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\AlexRogalskiy__proverbs
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\AlexRogalskiy__scala-patterns
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\AlexRogalskiy__spark-patterns: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\AlexRogalskiy__spark-patterns\\docs\\assets\\images\\687474703a2f2f6f70656e2d6461746173747564696f2e696f2f5f696d616765732f737061726b2d7365727665726c6573732d636c69656e742d6d6f64652e706e67.png'
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\alezhao__microsoft-devhack: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\alezhao__microsoft-devhack\\code\\Unity-Project\\Library\\com.unity.addressables\\aa\\WindowsUniversal\\WSAPlayer\\defaultlocalgroup_assets_all_1456902e8b710855339571ce14dcfba7.bundle'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\amigavision__AmigaVision
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Aminmiri82__PersonalGPTAssistant
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\anamariapanait10__FMI-BS-Resources: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\anamariapanait10__FMI-BS-Resources\\Year I\\sem 1\\Programarea algoritmilor\\subiecte_laborator\\rezolvari_subiectul_meu_lab\\venv\\Lib\\site-packages\\distutils-precedence.pth'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\anderseknert__opa-policy-composition
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\andreealalaaaa__ZeroToHero
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Andrei-Fabian-Pop__University: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\Andrei-Fabian-Pop__University\\Semester 2\\Data Structures and Algorithms\\FixedCapBiMap\\cmake-build-debug\\.cmake\\api\\v1\\reply\\directory-.-Debug-d0094a50bb2071803777.json'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\angrycub__nomad_example_jobs
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\AnikG-Org__devops-practice
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\appdevgbb__Project-Stormbreaker
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\appscode-cloud__ui-wizards: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\appscode-cloud__ui-wizards\\charts\\authenticationopenclustermanagementio-managedserviceaccount-editor\\crds\\authentication.open-cluster-management.io_managedserviceaccounts.yaml'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aptakube__kubespec.dev
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aquasecurity__postee
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aquasecurity__tracee-action
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aquasecurity__trivy: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\aquasecurity__trivy\\pkg\\fanal\\analyzer\\language\\java\\gradle\\testdata\\cache\\caches\\modules-2\\files-2.1\\junit\\junit\\4.13\\5c17760663fae422643fc859fd352c68a1d91bfc\\junit-4.13.pom'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aquasecurity__trivy-checks
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ARamsay118__ARamsay-HoloLens
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\argoproj__argo-cd
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\armenr__5thK8s
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\armstat__sdg-data-armenia
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Arsenio2044__arsenio-src
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\art-santos__language-database-benchmark: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\art-santos__language-database-benchmark\\Javascript\\Deno\\wasm\\target\\debug\\incremental\\MY_LIBRARY-1lgpul0vfy3dv\\s-gy734nobbi-3m6b80-f1itepp2zk7gje75mavjp65l6\\dep-graph.bin'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ArthurVardevanyan__HomeLab
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\artifacthub__hub
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\asbjorn-dev__MiniProjekt2023
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aserto-dev__policy-aona
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aserto-dev__runtime
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ashok-an__flask-opa
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\askmeegs__build-a-platform-with-krm
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\AtakanDengiz__video-conference-project
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\atheiman__katacoda-scenarios
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Avni-Sharma__gitopscon_na_2022_session
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-cloudformation__aws-cloudformation-templates
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-cloudformation__aws-guard-rules-registry
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-cloudformation__cloudformation-guard
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-ia__cfn-abi-aws-reference-guide
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__amazon-verified-permissions-asp-dotnet-core-custom-auth-policy-provider: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\aws-samples__amazon-verified-permissions-asp-dotnet-core-custom-auth-policy-provider\\TinyTodo.CDK\\PolicyStore\\PolicyTemplates\\TodoListSharedAccessWithResharePolicyTemplate.cedar'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__aws-cloud-custodian-sample-collection
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__aws-control-tower-cicd-cloud-custodian
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__aws-do-hyperpod
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__aws-infra-policy-as-code-with-terraform
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__aws-security-hub-findings-export
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__aws-securityhub-automated-remediations-workshop
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__awsome-distributed-training
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__cedar-policy-validation-pipeline
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__cfn101-workshop
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__container-patterns
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__eks-security-compromised-cluster-remediation
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__flux-eks-gitops-config
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__generative-ai-newsletter-app
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__hpc-applications
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__observability-with-amazon-opensearch
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__preventive-security-controls-in-pulumi-iac-pipeline
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__saas-authnz-demo-with-amazon-cognito
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__sample-emr-eks-hive-metastore-patterns
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-samples__sample-packages-for-aws-tnb
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws-solutions-library-samples__guidance-for-automated-geospatial-insights-engine-on-aws: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\aws-solutions-library-samples__guidance-for-automated-geospatial-insights-engine-on-aws\\infrastructure\\src\\shared\\customResources\\verifiedPermissions.CustomResource.ts'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\awslabs__avp-local-agent
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\awslabs__aws-config-rdk
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\awslabs__aws-iam-access-analyzer-policy-validation-config-rule
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\awslabs__aws-service-catalog-products: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\awslabs__aws-service-catalog-products\\operations\\service-catalog-puppet-pipeline-logs-exporter\\stacks\\service-catalog-puppet-pipeline-logs-exporter\\service-catalog-puppet-pipeline-logs-exporter.drawio'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\awslabs__cedar-access-control-for-k8s
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\awslabs__crossplane-on-eks
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\awslabs__idf-modules
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\awslabs__sustainability-scanner
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws__aws-app-mesh-examples
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws__aws-cdk: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\aws__aws-cdk\\packages\\@aws-cdk-testing\\framework-integ\\test\\aws-apigateway\\test\\authorizers\\integ.api-with-authorizer-and-method.js.snapshot\\integtest-restapi-with-authorizer-and-proxy.assets.json'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws__aws-eks-best-practices
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws__aws-parallelcluster: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\aws__aws-parallelcluster\\cli\\tests\\pcluster\\cli\\test_update_cluster\\TestUpdateClusterCommand\\test_resource_unchanged_due_to_queue_reorder\\pcluster_max_queue.config.yaml'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws__aws-sdk-go
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws__aws-sdk-net: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\aws__aws-sdk-net\\generator\\ProtocolTestsGenerator\\smithy-dotnet-codegen\\src\\main\\java\\software\\amazon\\smithy\\dotnet\\codegen\\customizations\\ProtocolTestCustomizations.java'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws__aws-sdk-php
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\aws__aws-sdk-ruby
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\AzeemGhumman__iqbal-demystified-dataset
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Azure-Samples__aks-labs
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Azure-Samples__azure-digital-twins-getting-started: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\Azure-Samples__azure-digital-twins-getting-started\\adt-adx-queries\\Dairy_operation_with_data_history\\Visualize_with_Grafana\\Factory Comparison by Machine Type, Output.json'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\azure-terraform-workshop__terraform-workshop-labs
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Azure__aks-app-routing-operator
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Azure__aks-ctf
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Azure__aks-engine-azurestack: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\Azure__aks-engine-azurestack\\vendor\\github.com\\Azure\\azure-sdk-for-go\\profile\\p20200901\\resourcemanager\\authorization\\armauthorization\\provideroperationsmetadata_client.go'
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Azure__ARO-RP: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\Azure__ARO-RP\\pkg\\operator\\controllers\\guardrails\\policies\\gktemplates-src\\aro-deny-master-toleration-taints\\gator-test\\not_allowed_create_pod_in_non_privileged_ns.yaml'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Azure__ato-toolkit
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Azure__azure-policy: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\Azure__azure-policy\\samples\\GuestConfiguration\\package-samples\\resource-modules\\PowerShellExecutionPolicy\\DscResources\\PowerShellExecutionPolicy\\PowerShellExecutionPolicy.psm1'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Azure__azure-remote-rendering
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Azure__AzureDefender-K8S-InClusterDefense
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Azure__Community-Policy: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\Azure__Community-Policy\\policyDefinitions\\App Service\\function-apps-should-authenticate-to-azure-container-registry-using-a-managed-identity\\azurepolicy.parameters.json'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Azure__draft
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Azure__sg-aks-workshop
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Azure__ShieldGuard
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\babywyrm__sysadmin
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\bacalhau-project__bacalhau
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\bacen__pix-dict-api
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\bachingo__TF2Vintage
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\back-stack__everything-as-code
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\badri-k7__aws-devops
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\balningau__gimste
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\banzaicloud__pipeline: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\banzaicloud__pipeline\\database\\migrations\\mysql\\1587125735_add_lb_range_column_from_vsphere_pke_clusters_table.up.sql_add_storage_secret_column_from_vsphere_pke_clusters_table.up.sql'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\baptistelabat__frydom
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\barringtonhaynes__lambda-extension-opa
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\bcgov__bcbox
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\bcgov__ckanext-bcgov-schema
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\bcgov__common-hosted-email-service
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\bcgov__MFIN-Data-Catalogue
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\bcgov__nr-forests-access-management
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\bcgov__pubcode
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Bearer__bearer
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\beiciliang__aws-bootcamp-cruddur-2023
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\BeryJu__k8s
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\besley__Slickflow
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\bikram20__opa-gatekeeper-examples
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\binxio__aws-cfn-update
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\bioinformatics-ua__montra
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\blockchain-working-group__blockchain-playbook
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\bluprince13__notesapp
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\bmeg__bmeg-etl
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\bmeg__iceberg
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\bmuschko__cks-crash-course
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\boostsecurityio__poutine
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\borgeby__jarl
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\boyism80__fb
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\BrunoReboul__ram-config-template: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\BrunoReboul__ram-config-template\\services\\monitor\\instances\\monitor_gce_target_https_proxy_ssl_policy\\constraints\\target_https_proxy_ssl_policy_required\\constraint.yaml'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\BrunoReboul__terraform-google-realtime-asset-monitor
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\btkrausen__hashicorp: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\btkrausen__hashicorp\\terraform\\Lab Prerequisites\\Section 09 - Read Generate and Modify Configuration\\Collection and Structure Types\\variable_validation\\terraform.auto.tfvars'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\build-on-aws__bookstore-demo-app-with-authz
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\busraylmz__DeepLearningModelVisualization: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\busraylmz__DeepLearningModelVisualization\\Assets\\Samples\\Mixed Reality Toolkit Examples\\2.7.2\\Demos - HandTracking\\Profiles\\GestureEventsConfigurationProfile.asset.meta'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\buttahtoast__helm-charts
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\buvis__clusters
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\C0nsultant__homelab-as-code
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\C5T__asbyrgi
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Calvitix__Stellaris-French-Translation-Pack
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\canonical__snapd
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Capstone-Projects-2022-Spring__project-anemone
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\carbonetes__brainiac: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\carbonetes__brainiac\\internal\\checker\\terraform\\rules\\aws\\aws_autoscaling_group_auto_scaling_groups_associated_with_load_balancer_are_utilizing_elastic_load_balancing_health_checks.rego'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\CBIIT__icdc-devops
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cdklabs__cdk-validator-cfnguard
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cdklabs__cdk-verified-permissions
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cedar-policy__cedar: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\cedar-policy__cedar\\cedar-policy-formatter\\tests\\cli-snapshots\\cedar_policy_formatter__pprint__fmt__tests__cli_sample_data_format@sandbox_c__policies_edited.cedar.snap'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cedar-policy__cedar-examples
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cedar-policy__cedar-integration-tests
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cedar-policy__cedar-java
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cedar-policy__cedar-local-agent
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cedar-policy__cedar-spec
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cedar-policy__highlightjs-cedar
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cedar-policy__prism-cedar
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cedar-policy__rfcs
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cedar-policy__vscode-cedar
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\celesrenata__nixos-k3s-configs
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\celest-dev__cedar-dart
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\celest-dev__celest
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ch-stark__governance-best-practises-for-apps
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ch-stark__maptoseveralstandards
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ch-stark__policies-demo
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ch-stark__policies-demo-blog
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\chaijunkin__home-ops
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\chainloop-dev__chainloop
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\chaitin__veinmind-tools
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\charlieegan3__policing-christmas-trees
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\charmed-kubernetes__jenkins
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\chaymaster__SourceSDK2013-Swelter
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Checkmarx__kics: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\Checkmarx__kics\\assets\\queries\\terraform\\aws\\group_with_privilege_escalation_by_actions_iam_PassRole_and_lambda_CreateFunction_and_lambda_InvokeFunction\\test\\negative1.tf'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\chef__automate
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\CHERIoT-Platform__network-stack
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\chipzoller__kyverno-pss
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\choria-io__aaasvc
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\choria-io__go-choria
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\chrisarcand__terraform-tests
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\chrisns__k8s-opa-boilerplate
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\christophwille__dotnet-opa-wasm
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Cigna__confectionery
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cioos-atlantic__metadata-waf
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\CircleCI-Public__circle-policy-agent
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\CircleCI-Public__circleci-cli
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cisagov__ScubaGear
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cisagov__ScubaGoggles
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cisco-kusanagi__mibs.snmplabs.com
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\CiscoDevNet__sdwan-devops
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cjoster__engagementstuff
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\claughinghouse__k8s-gitops
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\claytsay__Full-Life-The-RPG-Source-SDK-2013-
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cleardataeng__resource-policy-evaluation-library
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cloud-custodian__cloud-custodian: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\cloud-custodian__cloud-custodian\\tests\\data\\placebo\\test_elasticsearch_cross_cluster_search_connections_not_found\\es.DescribeOutboundCrossClusterSearchConnections_1.json'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cloud-custodian__helm-charts
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cloudavail__snippets: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\cloudavail__snippets\\php\\phpunit_simple_test\\vendor\\phpunit\\phpunit-mock-objects\\tests\\MockObject\\namespaced_class_implementing_interface_dont_call_parent_constructor.phpt'
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Cloudflare-Mining__Cloudflare-Datamining: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\Cloudflare-Mining__Cloudflare-Datamining\\data\\blog\\browser-rendering-api-ga-rolling-out-cloudflare-snippets-swr-and-bringing-workers-for-platforms-to-our-paygo-plans.html'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cloudify-community__eaas-example
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cloudkats__docker-tools
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\CloudNativeGBB__cluster-baseline
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cloudnativehero__cks-prep
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cloudposse__atmos
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cloudposse__terraform-provider-utils
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cloudposse__terraform-spacelift-cloud-infrastructure-automation
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cloudwu__stellaris_cn
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cncf__devstats
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cncf__landscape2-sites
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\CoderSaiya__BE_XDPMHDT
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Coit-IO__coit-simple-microservice
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\commercialhaskell__all-cabal-metadata
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\common-fate__cedar-validate-action
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ComradDoge__DogeEU4: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\ComradDoge__DogeEU4\\gfx\\interface\\government_mechanics\\legitimation_through_representation_mechanic\\legitimation_through_representation_mechanic_host_a_court_festival_button.dds'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\concourse__concourse
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\confidential-containers__cloud-api-adaptor
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\confidential-containers__trustee
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\confluentinc__policy-library-confluent-terraform
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ContainerSSH__examples
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\controlplaneio-fluxcd__d1-infra
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\controlplaneio__collie
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\controlplaneio__simulator
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\controlplaneio__threat-modelling-labs
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\controlplaneio__threat-modelling-zero-trust-talk
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\copslock__cisco-kusanagi_mibs.snmplabs.com
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\couchbase__perfrunner: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\couchbase__perfrunner\\tests\\n1ql\\pytpcc\\transactions\\n1ql_trans_6node_pytpcc_16core_100warehouse_240clients_replica2_dur_pers_to_maj_scancons_requestplus_magma_udf.test'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\courselabs__kubernetes
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\crag-h4k__gud-vim
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\credbull__credbull-defi
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\crossplane-contrib__crossplane-cdk8s
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\crossplane-contrib__provider-aws
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\crossplane-contrib__provider-upjet-aws
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\crossplane__tbs
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\CrowdStrike__cloud-pov
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\CrunchyData__postgres-operator
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\cvat-ai__cvat
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\CvGC__dict
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Cxs1103__Kubernetes.config
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\CZERTAINLY__CZERTAINLY-Auth-OPA-Policies
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\D-Kumar19__RegoPoilicies-Open-Policy-Agent
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\dadrus__heimdall
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\dany002__UBB-Computer-Science: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\dany002__UBB-Computer-Science\\Year 2\\Semester 2\\DBMS\\LAB2\\LAB2\\packages\\System.Configuration.ConfigurationManager.7.0.0\\buildTransitive\\net461\\System.Configuration.ConfigurationManager.targets'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\danzim__prometheus-provider
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\DaoCloud__dce-charts-repackage: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\DaoCloud__dce-charts-repackage\\charts\\opentelemetry-demo-lite\\opentelemetry-demo-lite\\charts\\opentelemetry-demo-lite\\charts\\opentelemetry-demo\\templates\\component.yaml'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\DataBassGit__AssistAF
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\DataBiosphere__consent
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\DataDog__kics: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\DataDog__kics\\assets\\queries\\terraform\\aws\\group_with_privilege_escalation_by_actions_iam_PassRole_and_lambda_CreateFunction_and_lambda_InvokeFunction\\test\\negative1.tf'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\DataDog__security-agent-policies
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\datadrivers__opa-policies
# ...
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\toyamarinyon__paywall-starter
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\TralahM__pytekswift
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\trendmicro__cloudone-container-security-helm
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\trevorbox__service-mesh-patterns: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\trevorbox__service-mesh-patterns\\egressgateway\\http-trusted-ca\\egressgateway-tls-origination-trusted-ca\\templates\\control-plane\\servicemeshcontrolplane-basic-install.yaml'
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\TrueTechLabs__fabric-trace: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\TrueTechLabs__fabric-trace\\application\\backend\\blockchain\\network\\organizations\\ordererOrganizations\\example.com\\orderers\\orderer.example.com\\msp\\cacerts\\ca.example.com-cert.pem'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\tuxpeople__k8s-homelab
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\tvories__k8s-gitops
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\TwitchPlaysPokemon__pbr-movesets
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\twplatformlabs__dps-starterkit-java: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\twplatformlabs__dps-starterkit-java\\skeleton\\service\\provider\\src\\main\\java\\io\\twdps\\starter\\example\\service\\provider\\account\\mapper\\AccountSubAccountEntityMapper.java'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\tx7do__kratos-authz
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ualberta-smr__PyMigBench
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\UBC-X-Lab__SurfShare: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\UBC-X-Lab__SurfShare\\opencvsharp_system_dependency\\system.runtime.compilerservices.unsafe.4.6.0\\package\\services\\metadata\\core-properties\\2d1d4c94aff8422385eb353421c39cf4.psmdcp'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ucsdlib__CA_lib_oration
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Udaara__sinasco
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\uhhhci__immersive-ngp
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\uhhhci__RealityFusion: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\uhhhci__RealityFusion\\RealityFusionUnity\\Assets\\External\\UnityRobotVisualization\\Runtime\\DefaultVisualizers\\Geometry\\AccelWithCovarianceStampedDefaultVisualizer.cs.meta'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ulissigroup__wherewulff
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\UNINETTSigma2__helm-charts
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\UniSiegenWiNeMe__AR-Instructions-Unity: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\UniSiegenWiNeMe__AR-Instructions-Unity\\Assets\\Samples\\Mixed Reality Toolkit Examples\\2.7.2\\Experimental - HandMenuLayout\\Materials\\HandMenu_AppButton_Backplate_Blue.mat'
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\UnstoppableMango__the-cluster: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\UnstoppableMango__the-cluster\\lib\\crds\\dotnet\\Acme\\V1\\Inputs\\ChallengeSpecSolverHttp01IngressPodTemplateSpecAffinityNodeAffinityPreferredDuringSchedulingIgnoredDuringExecutionArgs.cs'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\upbound__configuration-eks
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\uptycslabs__kspm-helm-charts
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\USA-RedDragon__home-cluster-flux
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\usnistgov__smartcitiesarchitecture
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\utilitywarehouse__gatekeeper-template-manifests
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\utilitywarehouse__semaphore-xds
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\utilitywarehouse__system-manifests
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Vaarun-C__DiagramsToCode
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\valex1984__katacoda-scenarios
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\vawser__Fallout-Mod
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\vazkarvishal__vishal-vazkar-poc-collection
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\VBAndCs__Vazor
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\vbandi__HL2-ResearchMode
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\veraison__services
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\VergeOps__k8s-rvstore: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\VergeOps__k8s-rvstore\\Advanced Kubernetes\\controller\\sample-controller\\pkg\\generated\\clientset\\versioned\\typed\\samplecontroller\\v1alpha1\\fake\\fake_samplecontroller_client.go'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Veridax__privapi
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Verizon__5GEdgeTutorials: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\Verizon__5GEdgeTutorials\\couchbase\\src\\Wavelength.Server\\Wavelength.Server.PerfTest\\reports\\2021-11-02_04.55.16_session_9a827a49\\nbomber_report_2021-11-02--04-56-17.csv'
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\vfarcic__cncf-demo: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\vfarcic__cncf-demo\\cdk8s\\imports\\databasesschemaheroio\\databasesschemaheroio_DatabaseSpecConnectionCassandraKeyspaceValueFromSsmSecretAccessKeyValueFromSecretKeyRef.go'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\vfiftyfive__dadjokes
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\vicenteherrera__starter-k8s
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Vikaspogu__openshift-multicluster
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ViktorUJ__cks
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\VitorAraujoAlcantara__youtube-samples
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\viva19__CloudCustodianRules
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Vizuri__openshift-fhir-rules-microservices
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\vmware-tanzu__kubeapps: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\vmware-tanzu__kubeapps\\dashboard\\src\\components\\DeploymentForm\\DeploymentFormBody\\BasicDeploymentForm\\TabularSchemaEditorTable\\TabularSchemaEditorTableRenderer.test.tsx'
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\vmware__dod-compliance-and-automation: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\vmware__dod-compliance-and-automation\\nsx\\3.x\\v1r3-stig\\ansible\\vmware-nsxt-3.x-stig-ansible-hardening\\roles\\t0rt\\templates\\t0rt_disable_multicast_on_interface.json.j2'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\vrk-kpa__opendata
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\vvhit-solutions__AzureDevops-Training: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\vvhit-solutions__AzureDevops-Training\\Kubernetes\\06. Ingress\\ingress-context-based-route\\kube-manifests\\04-IngressService-Manifests\\01-Ingress-Context-Path-Based-Routing.yml'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\WallarooLabs__wallaroo_blog_examples
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\WallarooLabs__wally
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\walt-id__waltid-ssikit
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\warroyo__tmc-bootstrap-automation
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\wealthbot-io__wealthbot
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\weaveworks__policy-library
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\web3infra-foundation__mega
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\web3privacy__explorer-data
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\webiny__webiny-js
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\WeCamp__pegski
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\whchoi98__myeks
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\wijez__crown_file_processing
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\willbossle__LINUXtips-PICK
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\willhausman__dopa
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\willhausman__dopa.cli
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\wkspower__wks-platform
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\wolfgangunger__aws-advanced
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\worldbank__sdg-metadata
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\wtchhb__SecHub
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\X-lab2017__open-digger
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\xchapter7x__hcunit
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\XenitAB__gatekeeper-library
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\XgridInc__xc3
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\xiyuii__Chaincode
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\xratq__group_project
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\XuananLe__RealtimeChat
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\y13i__cfn-schema
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\yantra-vinyasa__multi-cluster-configs
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\yeo__betterdev.link
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\YunosukeY__policy-for-pss
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\zakizadeh__MicroservicesBasedApp
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\Zamanof__4211_ru
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\zhenglin-charlie-li__Coding_In_University: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\zhenglin-charlie-li__Coding_In_University\\Blazor Webassembly\\MudBlazor_Theme\\src\\Acme.BookStore.Application.Contracts\\Permissions\\BookStorePermissionDefinitionProvider.cs'
# Error deleting C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\zMenta__Ulbra: [WinError 3] The system cannot find the path specified: 'C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\\zMenta__Ulbra\\Semestre_3_2022\\Estrutura_de_Dados\\Exercicio_aula_13_linked_list\\obj\\Debug\\net5.0\\Exercicio_aula_13_linked_list.GeneratedMSBuildEditorConfig.editorconfig'
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\zntrio__harp
# Deleted: C:/Users/fpatr/OneDrive/Documents/Adoption of policies as code in ML based application/clone\ZUGFeRD__quba-viewer
