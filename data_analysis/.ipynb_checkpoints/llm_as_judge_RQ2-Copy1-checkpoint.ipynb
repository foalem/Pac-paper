# %%
from langchain.prompts import PromptTemplate, FewShotPromptTemplate
import pandas as pd
from pprint import pprint
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from langchain_core.example_selectors import SemanticSimilarityExampleSelector
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_openai import ChatOpenAI
import os
import re
os.environ["OPENAI_API_KEY"] = ""

# %%
# Load agreement dataset
file_path = "disagreement_highlighted.xlsx"
df = pd.read_excel(file_path)
df
# Out:
#                                           full_name       Label_Patrick  \
# 0                                      a2-4am/4cade  Application System
# 1    AdminTurnedDevOps/kubernetes-real-world-course      Documentations
# 2                                alcideio/rbac-tool             Toolkit
# 3                           amigavision/AmigaVision  Application System
# 4               anderseknert/opa-policy-composition      Documentations
# ..                                              ...                 ...
# 394                          worldbank/sdg-metadata  Application System
# 395                           X-lab2017/open-digger             Toolkit
# 396                                    XgridInc/xc3             Toolkit
# 397                              yeo/betterdev.link      Documentations
# 398                             ZUGFeRD/quba-viewer  Application System
#
#            Label_Leuson      Last_commit_date     First_commit_date  \
# 0        Documentations  2025-05-10T04:14:23Z  2025-04-22T02:29:57Z
# 1        Documentations  2024-03-27T11:49:06Z  2023-06-03T14:10:35Z
# 2                DevOPs  2024-10-29T19:18:31Z  2022-06-16T05:14:36Z
# 3        Documentations  2025-05-10T20:19:25Z  2025-04-09T11:11:47Z
# 4        Documentations  2024-06-18T19:11:06Z  2021-03-24T21:07:35Z
# ..                  ...                   ...                   ...
# 394      Documentations  2024-11-20T16:06:52Z  2024-04-04T22:06:12Z
# 395  Application System  2025-05-16T09:24:25Z  2024-12-10T11:58:51Z
# 396             Toolkit  2024-04-19T06:35:38Z  2023-04-19T07:16:08Z
# 397      Documentations  2025-03-04T20:27:34Z  2024-10-14T02:23:52Z
# 398  Application System  2025-05-15T15:18:54Z  2024-12-05T17:05:25Z
#
#      HashiCorp Sentinel  Open Policy Agent (OPA)  Pulumi  \
# 0                     0                        0       0
# 1                     0                        0       0
# 2                     0                        0       0
# 3                     0                        0       0
# 4                     0                        8       0
# ..                  ...                      ...     ...
# 394                   0                        0       0
# 395                   0                        0       0
# 396                   0                        0       0
# 397                   0                        0       0
# 398                   0                        0       0
#
#      Cedar Policy Language (CPL)  Kyverno OSS  ...  has_sentinel  has_pulumi  \
# 0                              0            0  ...         False       False
# 1                              0            0  ...         False        True
# 2                              0            0  ...         False        True
# 3                              0            0  ...         False       False
# 4                              0            0  ...         False       False
# ..                           ...          ...  ...           ...         ...
# 394                            0            0  ...         False       False
# 395                            0            0  ...         False       False
# 396                            0            0  ...         False       False
# 397                            0            0  ...         False       False
# 398                            0            0  ...         False       False
#
#      has_cedar has_kyverno has_custodian  has_awsconfigcloudgaurd  \
# 0        False       False         False                     True
# 1        False       False         False                    False
# 2        False       False         False                    False
# 3        False       False          True                    False
# 4        False       False         False                    False
# ..         ...         ...           ...                      ...
# 394      False       False          True                    False
# 395      False       False          True                    False
# 396      False       False          True                    False
# 397      False       False          True                    False
# 398      False       False         False                     True
#
#      has_opagatekeeper contributors_count  \
# 0                False                 17
# 1                 True                  2
# 2                 True                 14
# 3                False                  4
# 4                False                  2
# ..                 ...                ...
# 394              False                 19
# 395              False                 47
# 396              False                 11
# 397              False                 10
# 398              False                 14
#
#                                         readme_content  Disagreement
# 0    # Is this page for you?\n\n[Download the lates...          True
# 1                                                  NaN         False
# 2    ![release](https://img.shields.io/github/v/rel...          True
# 3    # AmigaVision\n\n(The latest version of this d...          True
# 4    # opa-policy-composition\n\nExample policies d...         False
# ..                                                 ...           ...
# 394  # SDG Metadata Translation Pilot\n\nEvaluating...          True
# 395  # OpenDigger\n\n[![apache2](https://img.shield...          True
# 396  <br>\n\n[![License](https://img.shields.io/bad...         False
# 397  # Better Dev Link\n\nA weekly/daily news lette...         False
# 398  Quba-Viewer\n=============\n\nQuba-Viewer ([ho...         False
#
# [399 rows x 37 columns]

# %%
# Cleaning function for README content
def clean_readme(readme: str, max_chars=1500) -> str:
    if not isinstance(readme, str):
        return ""
    # Remove CLUSTER_DOMAIN
    readme = re.sub(r'\bCLUSTER_DOMAIN\b', '', readme, flags=re.IGNORECASE)
    # Remove URLs (http, https, www)
    readme = re.sub(r'https?://\S+|www\.\S+', '', readme)
    
    # Remove email addresses
    readme = re.sub(r'\b[\w\.-]+@[\w\.-]+\.\w+\b', '', readme)

    # Remove IP addresses
    readme = re.sub(r'\b(?:\d{1,3}\.){3}\d{1,3}\b', '', readme)
    readme = re.sub(r'!\[.*?\]\(.*?\)', '', readme)  # remove images
    readme = re.sub(r'\[.*?\]\(.*?\)', '', readme)   # remove markdown links
    readme = re.sub(r'<[^>]+>', '', readme)          # remove HTML
    # Remove all JSON-like structures (array or object)
    readme = re.sub(r'```json.*?```', '', readme, flags=re.DOTALL | re.IGNORECASE)  # remove fenced JSON blocks
    readme = re.sub(r'\[\s*\{.*?\}\s*\]', '', readme, flags=re.DOTALL)              # remove JSON arrays of objects
    readme = re.sub(r'\{\s*".*?".*?\}', '', readme, flags=re.DOTALL)                # remove standalone JSON objects
    
    readme = re.sub(r'\bcritical\b[.,;:!?"]*', '', readme, flags=re.IGNORECASE) # Remove the word "critical" (case-insensitive, whole word)
    readme = re.sub(r'"critical"\s*:\s*\{.*?\}(,)?', '', readme, flags=re.IGNORECASE | re.DOTALL) # Remove JSON block where "critical" is a key (non-greedy match for safety)
    # Remove symbols and digits
    readme = re.sub(r'[\"\'*#`~=|\\/\[\]\{\}\(\)\d]', '', readme)
    readme = re.sub(r'--+', ' ', readme)  # remove double dashes
    readme = re.sub(r'\s+', ' ', readme).strip()  # normalize spaces
    readme = re.sub(r'\s+', ' ', readme).strip()     # normalize spaces
    return readme
    # return readme[:max_chars] + ("..." if len(readme) > max_chars else "")

# %%
# Clean the README field
df["readme_content"] = df["readme_content"].apply(clean_readme)

# %%
df.fillna("None", inplace=True)

# %%
# Keep only agreed rows (Patrick == Leuson)
df_agreed = df[df["Label_Patrick"] == df["Label_Leuson"]].copy()
df_agreed.rename(columns={"Label_Patrick": "Label"}, inplace=True)
df_agreed
# Out:
#                                           full_name               Label  \
# 1    AdminTurnedDevOps/kubernetes-real-world-course      Documentations
# 4               anderseknert/opa-policy-composition      Documentations
# 5                             aptakube/kubespec.dev              DevOPs
# 6                               aquasecurity/postee  Application System
# 10                                 argoproj/argo-cd              DevOPs
# ..                                              ...                 ...
# 388                           walt-id/waltid-ssikit             Toolkit
# 393                           wkspower/wks-platform  Application System
# 396                                    XgridInc/xc3             Toolkit
# 397                              yeo/betterdev.link      Documentations
# 398                             ZUGFeRD/quba-viewer  Application System
#
#            Label_Leuson      Last_commit_date     First_commit_date  \
# 1        Documentations  2024-03-27T11:49:06Z  2023-06-03T14:10:35Z
# 4        Documentations  2024-06-18T19:11:06Z  2021-03-24T21:07:35Z
# 5                DevOPs  2025-04-27T13:19:31Z  2025-01-22T09:26:59Z
# 6    Application System  2024-09-28T05:52:51Z  2023-06-01T20:37:52Z
# 10               DevOPs  2025-05-15T20:58:43Z  2025-05-09T00:14:31Z
# ..                  ...                   ...                   ...
# 388             Toolkit  2024-07-16T13:58:10Z  2023-08-30T12:00:07Z
# 393  Application System  2025-05-14T16:40:41Z  2025-04-18T15:56:19Z
# 396             Toolkit  2024-04-19T06:35:38Z  2023-04-19T07:16:08Z
# 397      Documentations  2025-03-04T20:27:34Z  2024-10-14T02:23:52Z
# 398  Application System  2025-05-15T15:18:54Z  2024-12-05T17:05:25Z
#
#      HashiCorp Sentinel  Open Policy Agent (OPA)  Pulumi  \
# 1                     0                        0       0
# 4                     0                        8       0
# 5                     0                        0       0
# 6                     0                       38       0
# 10                    0                        0       0
# ..                  ...                      ...     ...
# 388                   0                        6       0
# 393                   0                       14       0
# 396                   0                        0       0
# 397                   0                        0       0
# 398                   0                        0       0
#
#      Cedar Policy Language (CPL)  Kyverno OSS  ...  has_sentinel  has_pulumi  \
# 1                              0            0  ...         False        True
# 4                              0            0  ...         False       False
# 5                              0          181  ...         False       False
# 6                              0            0  ...         False       False
# 10                             0           11  ...         False       False
# ..                           ...          ...  ...           ...         ...
# 388                            0            0  ...         False       False
# 393                            0            0  ...         False       False
# 396                            0            0  ...         False       False
# 397                            0            0  ...         False       False
# 398                            0            0  ...         False       False
#
#      has_cedar has_kyverno has_custodian  has_awsconfigcloudgaurd  \
# 1        False       False         False                    False
# 4        False       False         False                    False
# 5        False        True         False                    False
# 6        False       False         False                    False
# 10       False        True         False                    False
# ..         ...         ...           ...                      ...
# 388      False       False         False                    False
# 393      False       False         False                    False
# 396      False       False          True                    False
# 397      False       False          True                    False
# 398      False       False         False                     True
#
#      has_opagatekeeper contributors_count  \
# 1                 True                  2
# 4                False                  2
# 5                False                 11
# 6                False                 28
# 10               False               1654
# ..                 ...                ...
# 388              False                 17
# 393              False                 17
# 396              False                 11
# 397              False                 10
# 398              False                 14
#
#                                         readme_content  Disagreement
# 1                                                              False
# 4    opa-policy-composition Example policies demons...         False
# 5    Kubernetes Spec Explorer 👉 Live at - Tree view...         False
# 6    Notice: Postee is no longer under active devel...         False
# 10   Releases: !Release Version !Artifact HUB !SLSA...         False
# ..                                                 ...           ...
# 388  MOVED to the new repo here > SSI Kit by Use di...         False
# 393  WKS Platform !License On-line documentation Co...         False
# 396  !License !Docs !Slack !Open AI Reviewer !Code ...         False
# 397  Better Dev Link A weeklydaily news letter of r...         False
# 398  Quba-Viewer Quba-Viewer homepage is a cross pl...         False
#
# [183 rows x 37 columns]

# %%
df_agreed = df_agreed[["full_name", "topics", "description", "readme_content", "Label"]].reset_index(drop=True)
df_agreed
# Out:
#                                           full_name  \
# 0    AdminTurnedDevOps/kubernetes-real-world-course
# 1               anderseknert/opa-policy-composition
# 2                             aptakube/kubespec.dev
# 3                               aquasecurity/postee
# 4                                  argoproj/argo-cd
# ..                                              ...
# 178                           walt-id/waltid-ssikit
# 179                           wkspower/wks-platform
# 180                                    XgridInc/xc3
# 181                              yeo/betterdev.link
# 182                             ZUGFeRD/quba-viewer
#
#                                                 topics  \
# 0                                                 None
# 1                           opa,open-policy-agent,rego
# 2                                           kubernetes
# 3    aqua,automation,cloud-native,devsecops,docker,...
# 4    argo,argo-cd,cd,ci-cd,cicd,continuous-delivery...
# ..                                                 ...
# 178  blockchain,cryptography,decentralized-identifi...
# 179                                               None
# 180                        cloud,control,cost,optimize
# 181                                               None
# 182  e-rechnung,electron,electron-app,electronic-in...
#
#                                            description  \
# 0                                                 None
# 1    Example policies demonstrating policy composit...
# 2                             Kubernetes Spec Explorer
# 3    Notice: Postee is no longer under active devel...
# 4     Declarative Continuous Deployment for Kubernetes
# ..                                                 ...
# 178              All-In-One SSI infrastructure toolkit
# 179  WKS Platform is a cutting-edge Adaptive Case M...
# 180  XC3 is a cloud agnostic and risk free package ...
# 181                  Links to improve programing skill
# 182           Quba is a viewer for electronic invoices
#
#                                         readme_content               Label
# 0                                                           Documentations
# 1    opa-policy-composition Example policies demons...      Documentations
# 2    Kubernetes Spec Explorer 👉 Live at - Tree view...              DevOPs
# 3    Notice: Postee is no longer under active devel...  Application System
# 4    Releases: !Release Version !Artifact HUB !SLSA...              DevOPs
# ..                                                 ...                 ...
# 178  MOVED to the new repo here > SSI Kit by Use di...             Toolkit
# 179  WKS Platform !License On-line documentation Co...  Application System
# 180  !License !Docs !Slack !Open AI Reviewer !Code ...             Toolkit
# 181  Better Dev Link A weeklydaily news letter of r...      Documentations
# 182  Quba-Viewer Quba-Viewer homepage is a cross pl...  Application System
#
# [183 rows x 5 columns]

# %%
def split_train_test(df: pd.DataFrame, test_size: float = 0.2, random_state: int = 42):
    """
    Split the dataframe into a train and test set using stratified random sampling based on the 'Label' column.
    
    Parameters:
    - df (pd.DataFrame): The dataframe containing the data.
    - test_size (float): The proportion of the data to be used for testing (default is 0.2 for 80-20 split).
    - random_state (int): The seed used by the random number generator (default is 42).
    
    Returns:
    - train_df (pd.DataFrame): The training dataset.
    - test_df (pd.DataFrame): The testing dataset.
    """
    # Stratified split using 'Label' for stratification
    train_df, test_df = train_test_split(df, test_size=test_size, stratify=df['Label'], random_state=random_state)
    
    return train_df, test_df

# %%
df_agreed_train_data, df_agreed_test_data = split_train_test(df_agreed)

# %%
df_agreed_train_data
# Out:
#                             full_name  \
# 126  openshift/managed-cluster-config
# 163               sphenlee/waterwheel
# 54                  devxp-tech/gitops
# 48            deliciousmods/1956_beta
# 148   Resourcely-Inc/cloud-guardrails
# ..                                ...
# 13                    aws/aws-sdk-net
# 116        open-policy-agent/conftest
# 83         hogeschool/webdev-semester
# 31     cdklabs/cdk-validator-cfnguard
# 154      Scalr/sample-tf-opa-policies
#
#                                                 topics  \
# 126                                              osdv4
# 163                                               None
# 54   argo,argo-cd,argo-events,argo-rollouts,argo-wo...
# 48                                                None
# 148                                               None
# ..                                                 ...
# 13                                                None
# 116  kubernetes,open-policy-agent,openpolicyagent,r...
# 83                                                None
# 31                                                None
# 154                                               None
#
#                                            description  \
# 126  Static deployable artifacts for managed OSD cl...
# 163           A workflow scheduler based on petri-nets
# 54                               🏗️ GitOps Repository
# 48                               Road to 56 Beta Build
# 148  Open-source best practices for protecting a se...
# ..                                                 ...
# 13   The official AWS SDK for .NET. For more inform...
# 116  Write tests against structured configuration d...
# 83                                                None
# 31                                                None
# 154                                               None
#
#                                         readme_content               Label
# 126  managed-cluster-config repository This repo co...  Application System
# 163  Waterwheel Waterwheel is a job scheduler simil...  Application System
# 54   !main !Quality Gate Status !App Status !GitHub...              DevOPs
# 48   Road to Beta Build _Operation_Manstein .... Co...  Application System
# 148  Cloud Guardrails There are many best practices...      Documentations
# ..                                                 ...                 ...
# 13   AWS SDK for .NET !Gitter The AWS SDK for .NET ...             Toolkit
# 116  Conftest !Go Report Card !Netlify Conftest hel...             Toolkit
# 83                                                          Documentations
# 31   CDK CFN Guard Validator Plugin !cdk-constructs...             Toolkit
# 154  Terraform OPA policies examples !OPA tests !PR...      Documentations
#
# [146 rows x 5 columns]

# %%
df_agreed_test_data
# Out:
#                                              full_name  \
# 112                                NVIDIA/gpu-operator
# 72                               ghostunnel/ghostunnel
# 17   Azure-Samples/azure-digital-twins-getting-started
# 157                          sergueik/springboot_study
# 161                                       solo-io/hoot
# 108                                 microsoft/rego-cpp
# 24                           bacalhau-project/bacalhau
# 109              mongodb/mongodb-enterprise-kubernetes
# 123                 open-policy-agent/opa-docker-authz
# 20                                   Azure/ato-toolkit
# 1                  anderseknert/opa-policy-composition
# 28                                        borgeby/jarl
# 76                        google/gke-policy-automation
# 16                              Azure-Samples/aks-labs
# 176                              vmware-tanzu/kubeapps
# 128                 oscal-compass/compliance-to-policy
# 95                                   kondukto-io/kntrl
# 8             aws-samples/generative-ai-newsletter-app
# 86                                     intelops/genval
# 175                                  vfarcic/cncf-demo
# 114       open-cluster-management-io/policy-collection
# 6                          aws-samples/cfn101-workshop
# 43                               ContainerSSH/examples
# 111              Neurone/stellaris-italian-translation
# 151                                  SamYuan1990/Probe
# 144         raffaelespazzoli/openshift-enablement-exam
# 66                                 erkules/k8sworkshop
# 51         department-of-veterans-affairs/vets-website
# 104                         materialsproject/custodian
# 132  PacktPublishing/Terraform-Cookbook-Second-Edition
# 79   hashicorp/policy-library-aws-networking-terraform
# 60                             eclipse-tractusx/portal
# 150                                    rond-authz/rond
# 29                                 btkrausen/hashicorp
# 34                             cedar-policy/cedar-java
# 22                        Azure/azure-remote-rendering
# 115  open-cluster-management-io/policy-generator-pl...
#
#                                                 topics  \
# 112                         cuda,gpu,kubernetes,nvidia
# 72   crypto,go,hsm,keychain,pkcs11,proxy,security,s...
# 17                                                None
# 157                                 docker,spring-boot
# 161                                               None
# 108         c,cpp,opa,policy,policy-engine,python,rust
# 24   ai-art,ai-data-collection,ai-pipeline,batch-pr...
# 109  cloud-manager,kubernetes,kubernetes-operator,m...
# 123                           authorization,docker,opa
# 20                                                None
# 1                           opa,open-policy-agent,rego
# 28                  clojure,clojurescript,jvm,opa,rego
# 76                             gcp,gke,opa,policy,rego
# 16                                                None
# 176             carvel,deployment,flux,helm,kubernetes
# 128                                               None
# 95                                                None
# 8    amazon-verified-permissions,appsync,appsync-gr...
# 86                                                None
# 175                                               None
# 114                                               None
# 6                          aws,cloudformation,workshop
# 43                                        containerssh
# 111  italian,italiano,mod,paradox,stellaris,traduzi...
# 151  fabric,hyperledger-fabric,performance,performa...
# 144                                               None
# 66                                                None
# 51                     frontend,hacktoberfest,platform
# 104                                               None
# 132  arm-templates,azure-infrastructure-automation,...
# 79                                                None
# 60                                                None
# 150  authorization,hacktoberfest,openpolicyagent,rb...
# 29                                                None
# 34                                                None
# 22                                                None
# 115                                               None
#
#                                            description  \
# 112  NVIDIA GPU Operator creates, configures, and m...
# 72   A simple SSL/TLS proxy with mutual authenticat...
# 17   Resources for getting started with Azure Digit...
# 157  basic project collection exploring spring boot...
# 161                            code from hoot episodes
# 108  A C++ interpreter for the OPA policy language ...
# 24   Community-driven, simple, yet powerful framewo...
# 109             MongoDB Enterprise Kubernetes Operator
# 123  A policy-enabled authorization plugin for Docker.
# 20   On this page you'll find everything you need t...
# 1    Example policies demonstrating policy composit...
# 28   Jarl is an Open Policy Agent (OPA) evaluator f...
# 76   Tool and policy library for reviewing Google K...
# 16   Grab and go resources for hands-on learning ab...
# 176  A web-based UI for deploying and managing appl...
# 128  Compliance-to-Policy (C2P) provides the framew...
# 95   kntrl is an eBPF based runtime agent that moni...
# 8    The Generative AI Newsletter Application sampl...
# 86   Simplifies configuration management for a wide...
# 175                                               None
# 114  A collection of policy examples for Open Clust...
# 6                          AWS CloudFormation Workshop
# 43                               ContainerSSH examples
# 111              Mod per giocare Stellaris in italiano
# 151  Probe is a web GUI application with for Hyperl...
# 144                                               None
# 66                                                None
# 51                                 Frontend for VA.gov
# 104  A simple, robust and flexible just-in-time job...
# 132  Code Repository for Terraform Cookbook Second ...
# 79   Prescriptive Sentinel policies that can be use...
# 60                                Portal - Helm charts
# 150  A lightweight container for distributed securi...
# 29   Random code for HashiCorp related projects, tr...
# 34                Java bindings for the Cedar language
# 22          SDK and samples for Azure Remote Rendering
# 115  A Kustomize generator plugin to generate Open ...
#
#                                         readme_content               Label
# 112  !license !pipeline status !coverage report NVI...             Toolkit
# 72   Ghostunnel !license !release !docker !test !co...  Application System
# 17   page_type: sample languages: - json products: ...      Documentations
# 157                                                         Documentations
# 161  Hoot - Learn Kubernetes, Envoy, Istio, eBPF an...      Documentations
# 108  rego-cpp This project is an effort to create a...             Toolkit
# 24   Globally Distributed Compute Orchestrator ⚡Com...             Toolkit
# 109  MongoDB Enterprise Kubernetes Operator Welcome...              DevOPs
# 123  opa-docker-authz This project is used to show ...             Toolkit
# 20   Welcome to Azures DoD DevSecOps Enterprise Ope...      Documentations
# 1    opa-policy-composition Example policies demons...      Documentations
# 28   Jarl !build !codecov Jarl is an evaluator for ...             Toolkit
# 76   GKE Policy Automation This repository contains...             Toolkit
# 16   AKS-LABS Grab and go resources to learn about ...      Documentations
# 176  Kubeapps !Main Pipeline !Full Integration Pipe...              DevOPs
# 128                                                                Toolkit
# 95   kntrl is an eBPF based runtime agent that moni...              DevOPs
# 8    Generative AI Newsletter Application !Release ...               MLOps
# 86   !OpenSSF Best Practices !Go Report Card !Build...              DevOPs
# 175  Choose Your Own Adventure: The Treacherous Tre...      Documentations
# 114  Policy Collection A collection of policy examp...      Documentations
# 6    AWS CloudFormation - Workshop This repository ...      Documentations
# 43   !ContainerSSH - Launch Containers on Demand Co...      Documentations
# 111  Traduzione italiana di Stellaris Questo mod, c...  Application System
# 151  Probe !Build Status !Issues !GitHub pull reque...  Application System
# 144  openshift-enablement-exam The following instru...      Documentations
# 66                                                          Documentations
# 51   VA.gov !Build Status Table of Contents - - - -...  Application System
# 104  !Custodian logo !GitHub license !Linting !Test...             Toolkit
# 132  Terraform Cookbook, Second Edition This is the...      Documentations
# 79   AWS Networking Sentinel Policies for Terraform...             Toolkit
# 60   !LeadingRepository Portal: Helm charts This re...  Application System
# 150  !Build Statusgithub-actions-svggithub-actions ...             Toolkit
# 29   Support My Content Here: !Udemy !Github Sponso...      Documentations
# 34   cedar-java !Cedar Logo This repository contain...             Toolkit
# 22   Azure Remote Rendering > !NOTE > Please note t...             Toolkit
# 115  Policy Generator Overview The Policy Generator...             Toolkit

# %%
print(f"Train dataset size: {len(df_agreed_train_data)}")
print(f"Test dataset size: {len(df_agreed_test_data)}")
# Out:
# Train dataset size: 146
# Test dataset size: 37

# %%
# Keep only disagreed rows (Patrick == Leuson)
df_disagreed = df[df["Label_Patrick"] != df["Label_Leuson"]].copy()
# df_disagreed.rename(columns={"Label_Patrick": "Label"}, inplace=True)
df_disagreed = df_disagreed[["full_name", "topics", "description", "readme_content", "Label_Patrick", "Label_Leuson"]].reset_index(drop=True)
df_disagreed
# Out:
#                       full_name  \
# 0                  a2-4am/4cade
# 1            alcideio/rbac-tool
# 2       amigavision/AmigaVision
# 3    aquasecurity/tracee-action
# 4            aquasecurity/trivy
# ..                          ...
# 211   web3privacy/explorer-data
# 212            webiny/webiny-js
# 213              whchoi98/myeks
# 214      worldbank/sdg-metadata
# 215       X-lab2017/open-digger
#
#                                                 topics  \
# 0                                        hacktoberfest
# 1    access-control,acl,authorization,cluster,k8s-c...
# 2                    amiga,emulation,fpga,preservation
# 3         ebpf,github-actions,runtime-scanner,security
# 4    containers,devsecops,docker,go,golang,hacktobe...
# ..                                                 ...
# 211                                   database,privacy
# 212  aws,aws-lambda,cloud,cms,graphql,headless,head...
# 213                                               None
# 214                                               None
# 215        data-analysis,github,hacktoberfest,openrank
#
#                                            description  \
# 0    100s of games at your fingertips, as long as y...
# 1    Rapid7 | insightCloudSec | Kubernetes RBAC Pow...
# 2    The ultimate Amiga games & demo scene setup fo...
# 3                   Protect GitHub Actions with Tracee
# 4    Find vulnerabilities, misconfigurations, secre...
# ..                                                 ...
# 211                   Privacy Explorer Data Repository
# 212  Open-source serverless enterprise CMS. Include...
# 213                                               None
# 214                     SDG Metadata Translation Pilot
# 215                         Open source analysis tools
#
#                                         readme_content       Label_Patrick  \
# 0    Is this page for you? Download the latest Tota...  Application System
# 1    !release !Go Version !Build !License !Tweet in...             Toolkit
# 2    AmigaVision The latest version of this documen...  Application System
# 3    This project is for demonstration purpose only...      Documentations
# 4    !GitHub Releaserelease-imgrelease !Testtest-im...             Toolkit
# ..                                                 ...                 ...
# 211  WebPrivacy Now Data Repository You can createe...      Documentations
# 212  Open-Source Serverless Enterprise CMS !Prettie...  Application System
# 213                                                     Application System
# 214  SDG Metadata Translation Pilot Evaluating mach...  Application System
# 215  OpenDigger !apache ! !Node.js CI OpenDigger is...             Toolkit
#
#            Label_Leuson
# 0        Documentations
# 1                DevOPs
# 2        Documentations
# 3    Application System
# 4    Application System
# ..                  ...
# 211            Database
# 212             Toolkit
# 213      Documentations
# 214      Documentations
# 215  Application System
#
# [216 rows x 6 columns]

# %%
# Convert few-shot examples to list of dictionaries
def format_example(row):
    return {
        "input": f"""---
Project Name: {row['full_name']}
Topics: {row['topics']}
Description: {row['description']}
Readme Snippet: {row['readme_content']}
""",
        "output": row['Label']
    }

# %%
examples = df_agreed_train_data.apply(format_example, axis=1).tolist()

# %%
# examples[120]

# %%
# Compute semantic similarity
selector = SemanticSimilarityExampleSelector.from_examples(
    examples,
    OpenAIEmbeddings(),  # or HuggingFaceEmbeddings
    Chroma,
    k=4
)

# %%
import uuid

# %%
vectorstore_path = f"./chroma_index_{uuid.uuid4()}"
os.makedirs(vectorstore_path, exist_ok=True)

# %%
# # Compute semantic similarity
# selector = SemanticSimilarityExampleSelector.from_examples(
#     examples,
#     OpenAIEmbeddings(),  # or HuggingFaceEmbeddings
#     Chroma,
#     k=3,
#     input_keys=["input"],
#     vectorstore_kwargs={"persist_directory": vectorstore_path}
# )

# %%
# Format example rows into dictionary format expected by LangChain
example_prompt = PromptTemplate(
    input_variables=["input", "output"],
    template="{input}\nLabel: {output}"
)

# %%
# Compose final few-shot prompt template
prefix = """You are an expert in software engineering and OSS analysis. Your task is to classify open-source projects into one of the following predefined categories based on their purpose, description, and README content.

The categories are:

DevOps: Projects that leverage infrastructure and operations tools (e.g., Kubernetes, Ansible, Docker) to automate the provisioning, deployment, and governance of software applications.

Toolkit: Standalone libraries, frameworks, APIs, plugins, or modules that offer reusable functionalities or components to simplify software development.

MLOps: These projects combine AI/ML models with DevOps tools and practices to automate the ML lifecycle, including model training, deployment, monitoring, and governance.

Documentation: Projects that primarily serve as documentation, tutorials, workshops, demo or basic projects example, use case project.

AI/Research: Academic or experimental projects involving AI/ML models or techniques.

Application System: These are software projects or programs. They may include web applications or traditional systems without AI/ML components.

Each example below contains the project’s metadata and its correct category label. Learn from these examples to classify the next project.
"""

suffix = """---
Project Name: {full_name}
Topics: {topics}
Description: {description}
Readme Snippet: {readme_snippet}
Label:
Rationale:"""

# %%
# Compute Prompt
prompt = FewShotPromptTemplate(
    example_selector=selector,
    example_prompt=example_prompt,
    prefix=prefix,
    suffix=suffix,
    input_variables=["full_name", "topics", "description", "readme_snippet"]
)

# %%
# Initialize the model with gpt-4o-mini and your API key
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.2
)

# %%
# Compose your chain (prompt must be previously defined and valid)
chain = prompt | llm

# %%
def classify_projects_with_llm(df, chain):
    results = []

    for _, row in df.iterrows():
        input_data = {
            "full_name": row.get("full_name", "None"),
            "topics": row.get("topics", "None"),
            "description": row.get("description", "None"),
            "readme_snippet": row.get("readme_content", "None")
        }

        try:
            response = chain.invoke(input_data)
            response_text = response.content.strip()

            # Simple parsing based on the expected response format
            label_line = response_text.split('\n')[0]
            label = label_line.replace("Label:", "").strip()

            rationale = "\n".join(response_text.split('\n')[1:]).strip()

        except Exception as e:
            label = "ERROR"
            rationale = f"Error during classification: {e}"

        results.append({
            "predicted_label": label,
            "rationale": rationale
        })

    # Combine results with the original dataframe
    result_df = df.copy()
    result_df = result_df.reset_index(drop=True)
    result_df[["predicted_label", "rationale"]] = pd.DataFrame(results)

    return result_df

# %%
classified_test_df = classify_projects_with_llm(df_agreed_test_data, chain)

# Show result
classified_test_df[["full_name", "Label", "predicted_label", "rationale"]].head()
# Out:
#                                            full_name               Label  \
# 0                                NVIDIA/gpu-operator             Toolkit
# 1                              ghostunnel/ghostunnel  Application System
# 2  Azure-Samples/azure-digital-twins-getting-started      Documentations
# 3                          sergueik/springboot_study      Documentations
# 4                                       solo-io/hoot      Documentations
#
#       predicted_label                                          rationale
# 0              DevOps  Rationale: The NVIDIA GPU Operator is designed...
# 1              DevOps  Rationale: Ghostunnel is a TLS proxy that prov...
# 2       Documentation  Rationale: The project "Azure-Samples/azure-di...
# 3  Application System  Rationale: The project "sergueik/springboot_st...
# 4       Documentation  Rationale: The project "solo-io/hoot" is prima...

# %%
df_disagreed.head()
# Out:
#                     full_name  \
# 0                a2-4am/4cade
# 1          alcideio/rbac-tool
# 2     amigavision/AmigaVision
# 3  aquasecurity/tracee-action
# 4          aquasecurity/trivy
#
#                                               topics  \
# 0                                      hacktoberfest
# 1  access-control,acl,authorization,cluster,k8s-c...
# 2                  amiga,emulation,fpga,preservation
# 3       ebpf,github-actions,runtime-scanner,security
# 4  containers,devsecops,docker,go,golang,hacktobe...
#
#                                          description  \
# 0  100s of games at your fingertips, as long as y...
# 1  Rapid7 | insightCloudSec | Kubernetes RBAC Pow...
# 2  The ultimate Amiga games & demo scene setup fo...
# 3                 Protect GitHub Actions with Tracee
# 4  Find vulnerabilities, misconfigurations, secre...
#
#                                       readme_content
# 0  Is this page for you? Download the latest Tota...
# 1  !release !Go Version !Build !License !Tweet in...
# 2  AmigaVision The latest version of this documen...
# 3  This project is for demonstration purpose only...
# 4  !GitHub Releaserelease-imgrelease !Testtest-im...

# %%
classified_test_df.to_excel("Test_data_evaluation.xlsx")

# %%
classified_df = classify_projects_with_llm(df_disagreed, chain)

# Show result
classified_df[["full_name", "Label_Patrick", "Label_Leuson", "predicted_label", "rationale"]].head()
# Out:
#                     full_name       Label_Patrick        Label_Leuson  \
# 0                a2-4am/4cade  Application System      Documentations
# 1          alcideio/rbac-tool             Toolkit              DevOPs
# 2     amigavision/AmigaVision  Application System      Documentations
# 3  aquasecurity/tracee-action      Documentations  Application System
# 4          aquasecurity/trivy             Toolkit  Application System
#
#       predicted_label                                          rationale
# 0  Application System  Rationale: The project "4cade" is focused on p...
# 1              DevOps  Rationale: The project "alcideio/rbac-tool" fo...
# 2  Application System  Rationale: The project "AmigaVision" is primar...
# 3              DevOps  Rationale: The project "aquasecurity/tracee-ac...
# 4              DevOps  Rationale: The project "aquasecurity/trivy" is...

# %%
classified_df.to_excel("llm_annotated_data.xlsx")

# %%
classified_test_df = pd.read_excel("Test_data_evaluation.xlsx")

# %%
def evaluate_llm_predictions_sklearn(df, label_col="Label", pred_col="predicted_label"):
    # Standardize text: lowercase and strip
    y_true = df[label_col].astype(str).str.strip().str.lower()
    y_pred = df[pred_col].astype(str).str.strip().str.lower()

    # Accuracy
    accuracy = accuracy_score(y_true, y_pred)

    # Classification report
    report = classification_report(y_true, y_pred, output_dict=True)

    # Confusion matrix
    labels = sorted(set(y_true) | set(y_pred))  # all labels that appear in either column
    cm = confusion_matrix(y_true, y_pred, labels=labels)

    return {
        "accuracy": round(accuracy, 3),
        "classification_report": report,
        "confusion_matrix": cm,
        "labels": labels
    }

# %%
results = evaluate_llm_predictions_sklearn(classified_test_df)

print("✅ Accuracy:", results["accuracy"])
print("\n📋 Classification Report:")
pprint(results["classification_report"])

print("\n📊 Confusion Matrix:")
cm_df = pd.DataFrame(results["confusion_matrix"], index=results["labels"], columns=results["labels"])
print(cm_df)
# Out:
# ✅ Accuracy: 0.351
#
# 📋 Classification Report:
# {'accuracy': 0.35135135135135137,
#  'application system': {'f1-score': 0.5,
#                         'precision': 0.6666666666666666,
#                         'recall': 0.4,
#                         'support': 5.0},
#  'devops': {'f1-score': 0.4444444444444444,
#             'precision': 0.2857142857142857,
#             'recall': 1.0,
#             'support': 4.0},
#  'documentation': {'f1-score': 0.0,
#                    'precision': 0.0,
#                    'recall': 0.0,
#                    'support': 0.0},
#  'documentations': {'f1-score': 0.0,
#                     'precision': 0.0,
#                     'recall': 0.0,
#                     'support': 14.0},
#  'macro avg': {'f1-score': 0.3460038986354776,
#                'precision': 0.38095238095238093,
#                'recall': 0.47692307692307695,
#                'support': 37.0},
#  'mlops': {'f1-score': 0.5,
#            'precision': 0.3333333333333333,
#            'recall': 1.0,
#            'support': 1.0},
#  'toolkit': {'f1-score': 0.631578947368421,
#              'precision': 1.0,
#              'recall': 0.46153846153846156,
#              'support': 13.0},
#  'weighted avg': {'f1-score': 0.3510352457720879,
#                   'precision': 0.48133848133848134,
#                   'recall': 0.35135135135135137,
#                   'support': 37.0}}
#
# 📊 Confusion Matrix:
#                     application system  devops  documentation  documentations  \
# application system                   2       2              0               0
# devops                               0       4              0               0
# documentation                        0       0              0               0
# documentations                       1       2             11               0
# mlops                                0       0              0               0
# toolkit                              0       6              0               0
#
#                     mlops  toolkit
# application system      1        0
# devops                  0        0
# documentation           0        0
# documentations          0        0
# mlops                   1        0
# toolkit                 1        6
# C:\Users\fpatr\anaconda3\envs\Pac\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\fpatr\anaconda3\envs\Pac\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\fpatr\anaconda3\envs\Pac\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\fpatr\anaconda3\envs\Pac\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\fpatr\anaconda3\envs\Pac\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\fpatr\anaconda3\envs\Pac\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
first_row = df_agreed_test_data.iloc[10]

full_name = first_row['full_name']
topics = first_row['topics']
description = first_row['description']
readme_content = first_row['readme_content']
label = first_row['Label']

# # Print them (optional)
# print("Full name:", full_name)
# print("Topics:", topics)
# print("Description:", description)
# print("Readme:", readme_content)
# print("Label:", label)

# %%
input_example = {
    "full_name": full_name,
    "topics": topics,
    "description": description,
    "readme_snippet": readme_content
}

# %%
selected = selector.select_examples(input_example)

# for i, ex in enumerate(selected):
#     print(f"\n--- Example {i+1} ---")
#     print(example_prompt.format(**ex))

# %%
rendered_prompt = prompt.format(**input_example)
# print(rendered_prompt)

# %%
# Example project classification input
response = chain.invoke({
    "full_name": full_name,
    "topics": topics,
    "description": description,
    "readme_snippet": readme_content
})

# %%
# print(chain.input_schema.schema())

# %%
# Print LLM output
print(response.content)
# Out:
# Label: Documentation
#
# Rationale: The project "anderseknert/opa-policy-composition" provides example policies demonstrating policy composition in Rego, which indicates that it serves as a resource for learning and understanding how to use OPA with policy composition. The README snippet mentions that these examples accompany a blog post, further emphasizing its purpose as a documentation resource rather than a standalone tool or application.

# %%
df_agreed_test_data.head(10)
# Out:
#                                              full_name  \
# 112                                NVIDIA/gpu-operator
# 72                               ghostunnel/ghostunnel
# 17   Azure-Samples/azure-digital-twins-getting-started
# 157                          sergueik/springboot_study
# 161                                       solo-io/hoot
# 108                                 microsoft/rego-cpp
# 24                           bacalhau-project/bacalhau
# 109              mongodb/mongodb-enterprise-kubernetes
# 123                 open-policy-agent/opa-docker-authz
# 20                                   Azure/ato-toolkit
#
#                                                 topics  \
# 112                         cuda,gpu,kubernetes,nvidia
# 72   crypto,go,hsm,keychain,pkcs11,proxy,security,s...
# 17                                                None
# 157                                 docker,spring-boot
# 161                                               None
# 108         c,cpp,opa,policy,policy-engine,python,rust
# 24   ai-art,ai-data-collection,ai-pipeline,batch-pr...
# 109  cloud-manager,kubernetes,kubernetes-operator,m...
# 123                           authorization,docker,opa
# 20                                                None
#
#                                            description  \
# 112  NVIDIA GPU Operator creates, configures, and m...
# 72   A simple SSL/TLS proxy with mutual authenticat...
# 17   Resources for getting started with Azure Digit...
# 157  basic project collection exploring spring boot...
# 161                            code from hoot episodes
# 108  A C++ interpreter for the OPA policy language ...
# 24   Community-driven, simple, yet powerful framewo...
# 109             MongoDB Enterprise Kubernetes Operator
# 123  A policy-enabled authorization plugin for Docker.
# 20   On this page you'll find everything you need t...
#
#                                         readme_content               Label
# 112  !license !pipeline status !coverage report NVI...             Toolkit
# 72   Ghostunnel !license !release !docker !test !co...  Application System
# 17   page_type: sample languages: - json products: ...      Documentations
# 157                                                         Documentations
# 161  Hoot - Learn Kubernetes, Envoy, Istio, eBPF an...      Documentations
# 108  rego-cpp This project is an effort to create a...             Toolkit
# 24   Globally Distributed Compute Orchestrator ⚡Com...             Toolkit
# 109  MongoDB Enterprise Kubernetes Operator Welcome...              DevOPs
# 123  opa-docker-authz This project is used to show ...             Toolkit
# 20   Welcome to Azures DoD DevSecOps Enterprise Ope...      Documentations

# %%
# Print them (optional)
print("Full name:", full_name)
print("Topics:", topics)
print("Description:", description)
print("Readme:", readme_content)
print("Label:", label)
# Out:
# Full name: solo-io/hoot
# Topics: None
# Description: code from hoot episodes
# Readme: Hoot - Learn Kubernetes, Envoy, Istio, eBPF and GraphQL We understand it is important for you to learn Envoy, Istio, Kubernetes, eBPF and GraphQL as part of your journey to cloud native so you can make sense of any technology or architecture decision. Hoot is designed to help you learn these technologies so you can be well prepared at your job! Upcoming episodes View Episode Calendar Add Google Calendar Suggest a topic Please open an issue if you have an idea for a topic we should cover or a guest we should invite. Previous episodes This repo contains the code, slides and show notes for our Hoot series: The full playlist: - Youtube Playlist Videos: - Episode : Intro to envoy - - Episode : Observe envoy - - Episode : Securing enovy - - Episode : Envoy, XDS - - Episode : Envoy filters - - Episode : Envoy WASM filters - - Episode : Into to OPA - - Episode : OPA + Envoy - - Episode : GitOps + Flux - - Episode : Waypoint - - Episode : Advanced Istio Configuration with Envoy CRDs - Episode : Hitless Deploys - - Episode : Approaches to Multi-Cluster Networking in Service Mesh and Istio - - Episode : Istio Debugging - - Episode : Envoy + External Services - - Episode : Adding real-time updates to OPA with OPAL - - Episode : Envoy + Rate Limiting - - Episode : Envoy Filters - - Episode : eBPF: A Top-Down view - - Episode : -Click Upgrade to Istio . using Helm - - Episode : Istio In Action Book Highlight - - Episode : Accelerate your mesh with eBPF and Merbridge - - Episode : HOW to increase application resiliency for Kubernetes services running on Spot VMs - - Episode : Debug Envoy Configs and Analyze Access Logs - - Episode : Istio + Spire + VM - - Episode : Declarative Kubernetes Lifecycle Management Across Multi-ClustersClouds with Cluster API - - Episode : Gloo Cilium and Istio Seamlessly Together - - Episode : What is new in Istio .? - - Episode : Porting eBPF applications to BumbleBee - - Episode : HTTP With Envoy Explained - - Episode : Cilium L Policies vs Istio’s - - Episode : GraphQL for Developers or Platform Team? - - Episode : Speed your Istio development environment with vcluster - - Episode : Optional Sidecar? A Tour of Cilium Service Mesh - - Episode : Successes? Lessons? Istio @ Quizlet - - Episode : Istio ambient, what does it mean to you? - - EPisode : Common Questions for Istio Ambient - - Episode : What Istio ambient means for your wallet - - Episode : Ambient and Gloo Mesh - - Episode : Ask Us Anything about Istio Ambient Explained Book - - Episode : What is NEW in Istio .? - - Episode : Rust-based ztunnel for Istio ambient mesh? - - Episode : Successes? Lessons? Istio @ Virtru - - Episode : Overview of SPIRE - - Episode : Solve Large Volumes of Metrics Challenges with Istio Service Mesh and Open Telemetry - - Episode : Istio Ambient Service Mesh & Rust-Based Ztunnel Update - - Episode : Rotating certificates in Istio - - Episode : GitOps and Service Mesh for Resilient and Secure Operations - - Episode : Configuring external services with Istios ServiceEntry - - Episode : Kubernetes Networking and Cilium - Part - - Episode : Kubernetes Networking and Cilium - Part - - Episode : Istio and Open Policy Agent OPA - - Episode : Cut Service Mesh Overhead by % or More with Istio Ambient Mesh -
# Label: Documentations

# %%
# Re-import libraries after kernel reset
# from langchain.prompts import PromptTemplate, FewShotPromptTemplate
# import pandas as pd
# from sklearn.model_selection import train_test_split

# Load agreement dataset
file_path = "/mnt/data/RQ2_Agreement_Dataset.xlsx"
df = pd.read_excel(file_path)

# Keep only agreed rows (Patrick == Leuson)
df_agreed = df[df["Label_Patrick"] == df["Label_Leuson"]].copy()
df_agreed.rename(columns={"Label_Patrick": "Label"}, inplace=True)

# Sample 80% for few-shot, 20% for testing
few_shot_examples, test_set = train_test_split(df_agreed, test_size=0.2, random_state=42)

# Format example rows into dictionary format expected by LangChain
example_prompt = PromptTemplate(
    input_variables=["full_name", "topics", "description", "readme", "label"],
    template=(
        "---\n"
        "Project Name: {full_name}\n"
        "Topics: {topics}\n"
        "Description: {description}\n"
        "Readme Snippet: {readme}\n"
        "Label: {label}"
    )
)

# Convert few-shot examples to list of dictionaries
examples = [
    {
        "full_name": row["full_name"],
        "topics": row["topics"] if pd.notnull(row["topics"]) else "None",
        "description": row["description"] if pd.notnull(row["description"]) else "None",
        "readme": row["readme_content"][:300] if pd.notnull(row["readme_content"]) else "None",
        "label": row["Label"]
    }
    for _, row in few_shot_examples.iterrows()
]

# Compose final few-shot prompt template
prefix = """You are an expert in software engineering and OSS analysis. Your task is to classify open-source projects into one of the following predefined categories based on their purpose, description, and README content.

The categories are:

DevOps: Projects that leverage infrastructure and operations tools (e.g., Kubernetes, Ansible, Docker) to automate the provisioning, deployment, and governance of software applications.

Toolkit: Standalone libraries, frameworks, APIs, plugins, or modules that offer reusable functionalities or components to simplify software development.

MLOps: These projects combine AI/ML models with DevOps tools and practices to automate the ML lifecycle, including model training, deployment, monitoring, and governance.

Documentation: Projects that primarily serve as documentation, tutorials, workshops, demo or use case.

AI/Research: Academic or experimental projects involving AI/ML models or techniques.

Application System: These are software projects or programs. They may include web applications or traditional systems without AI/ML components.

Each example below contains the project’s metadata and its correct category label. Learn from these examples to classify the next project.
"""

suffix = """---
Project Name: {full_name}
Topics: {topics}
Description: {description}
Readme Snippet: {readme}
Label:"""

# Construct the FewShotPromptTemplate
few_shot_prompt = FewShotPromptTemplate(
    examples=examples,
    example_prompt=example_prompt,
    prefix=prefix,
    suffix=suffix,
    input_variables=["full_name", "topics", "description", "readme"]
)

# Prepare one test instance to preview the prompt
test_row = test_set.iloc[0]
final_prompt = few_shot_prompt.format(
    full_name=test_row["full_name"],
    topics=test_row["topics"] if pd.notnull(test_row["topics"]) else "None",
    description=test_row["description"] if pd.notnull(test_row["description"]) else "None",
    readme=test_row["readme_content"][:300] if pd.notnull(test_row["readme_content"]) else "None"
)

final_prompt[:1500]  # Only return preview of the final prompt text due to length
